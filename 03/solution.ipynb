# %%
import numpy as np
import re

from operator import itemgetter

# %%
def prepare_input(input):
    input.insert(0, '.' * len(input[0]))
    input.append('.' * len(input[0]))

    return [f'.{line}.' for line in input]

# %%
def get_directions(length):
    directions = [
        (-1,1),
        (-1,0),
        (-1,-1)
    ]
    for i in range(length):
        directions.append((i,1))
        directions.append((i,-1))
    directions.append((length,1))
    directions.append((length,0))
    directions.append((length,-1))

    return directions

def get_field(length):
    directions = []
    for i in range(-length, length+1, 1):
        directions.append((i,-1))
    for i in range(-length, length+1, 1):
        directions.append((i,0))
    for i in range(-length, length+1, 1):
        directions.append((i,1))
    return directions

# %%
def get_numbers(input, debug = False):
    input = prepare_input(input)
    nums = []

    for row, line in enumerate(input):
        numbers = re.findall(r'\d+', line)
        if len(numbers) == 0:
            continue
        start = 0
        if debug: print(f'...{row}...')
        for number in numbers:
            found = False
            start_search = line.find(number, start)
            for y,x in get_directions(len(number)):
                if found: 
                    continue
                if debug:
                    print(x, y, x+row, y+start, input[x+row][y+start_search])
                if re.match(r'[^\.\d]', input[x+row][y+start_search]) and not found:
                    found = True
                    if debug: print(number, input[x+row][y+start_search])
                    nums.append(int(number))
            start = start_search + len(number)

    return nums

# %%
def get_valiate(input, debug = False):
    return sum(get_numbers(input, debug))

# %%
def get_gears(input, debug=False):
    input = prepare_input(input)
    num_len = max([len(num) for num in re.findall(r'\d+', ''.join(input))])
    directions = get_field(num_len)
    sum = 0

    for row, line in enumerate(input):
        stars = re.findall(r'\*', line)
        if len(stars) == 0:
            continue
        start = 0
        if debug: print(f'...{row}...')
        for star in stars:
            start_search = line.find(star, start)
            field = ''
            cur_x = directions[0][1]
            for y,x in directions:
                if x != cur_x: field += '\n'
                if 0 <= x+row < len(input) and 0 <= y+start_search < len(input[x+row]):
                    cur = input[x+row][y+start_search]
                    if not re.match(r'\d', cur) and cur != '*': cur = '.'
                    field += cur
                cur_x = x
            nums = get_numbers(field.strip().split('\n'))
            if debug: print(field, '\nNUMS:', nums, np.prod(nums))
            if len(nums) > 1:
                sum += np.prod(nums)
    return sum

# %%
input = '''467..114...
.*.........
..35..633..
......#....
617*.......
.....+.58.*
..592......
......755..
...$.*.....
.664.598...'''.split('\n')

get_valiate(input)
# Out:
# 4361

# %%
get_gears(input, True)
# Out:
# ...5...
# .467..
# ..*...
# ...35.
# NUMS: [467, 35] 16345
# ...8...
# .......
# 617*...
# .......
# NUMS: [617] 617
# ...9...
# .....
# 58.*.
# .....
# NUMS: [] 1.0
# ...12...
# ....755
# ...*...
# 64.598.
# NUMS: [755, 598] 451490
# 467835

# %%
input = []

with open('./input.txt', 'r') as f:
    input = [x.strip() for x in f.readlines()] #

get_valiate(input)
# Out:
# 528799

# %%
get_gears(input, True)
# Out:
# ...3...
# 662....
# ...*...
# .360...
# NUMS: [662, 360] 238320
# 662....
# ...*...
# .360...
# NUMS: [662, 360] 238320
# 662....
# ...*...
# .360...
# NUMS: [662, 360] 238320
# ...4...
# 6..855.
# ...*...
# ...379.
# NUMS: [855, 379] 324045
# 6..855.
# ...*...
# ...379.
# NUMS: [855, 379] 324045
# 6..855.
# ...*...
# ...379.
# NUMS: [855, 379] 324045
# 6..855.
# ...*...
# ...379.
# NUMS: [855, 379] 324045
# ...5...
# 664....
# ...*...
# .482.39
# NUMS: [664, 482] 320048
# 664....
# ...*...
# .482.39
# NUMS: [664, 482] 320048
# 664....
# ...*...
# .482.39
# NUMS: [664, 482] 320048
# 664....
# ...*...
# .482.39
# NUMS: [664, 482] 320048
# 664....
# ...*...
# .482.39
# NUMS: [664, 482] 320048
# 664....
# ...*...
# .482.39
# NUMS: [664, 482] 320048
# ...7...
# ....566
# ...*...
# ..11...
# NUMS: [566, 11] 6226
# ....566
# ...*...
# ..11...
# NUMS: [566, 11] 6226
# ....566
# ...*...
# ..11...
# NUMS: [566, 11] 6226
# ....566
# ...*...
# ..11...
# NUMS: [566, 11] 6226
# ....566
# ...*...
# ..11...
# NUMS: [566, 11] 6226
# ...8...
# .797...
# ...*...
# ..778..
# NUMS: [797, 778] 620066
# .797...
# ...*...
# ..778..
# NUMS: [797, 778] 620066
# ...9...
# ..870..
# ...*...
# ..706..
# NUMS: [870, 706] 614220
# ...10...
# ..238..
# ...*...
# .69....
# NUMS: [238, 69] 16422
# ..238..
# ...*...
# .69....
# NUMS: [238, 69] 16422
# ..238..
# ...*...
# .69....
# NUMS: [238, 69] 16422
# ..238..
# ...*...
# .69....
# NUMS: [238, 69] 16422
# ...11...
# 249....
# ...*..3
# .587...
# NUMS: [249, 587] 146163
# 249....
# ...*..3
# .587...
# NUMS: [249, 587] 146163
# 249....
# ...*..3
# .587...
# NUMS: [249, 587] 146163
# 249....
# ...*..3
# .587...
# NUMS: [249, 587] 146163
# ...13...
# 844.885
# ...*...
# .......
# NUMS: [844, 885] 746940
# 844.885
# ...*...
# .......
# NUMS: [844, 885] 746940
# ...14...
# ...826.
# ...*...
# 640..82
# NUMS: [826, 640] 528640
# ...826.
# ...*...
# 640..82
# NUMS: [826, 640] 528640
# ...826.
# ...*...
# 640..82
# NUMS: [826, 640] 528640
# ...15...
# ..213..
# 6..*...
# ....325
# NUMS: [213, 325] 69225
# ..213..
# 6..*...
# ....325
# NUMS: [213, 325] 69225
# ..213..
# 6..*...
# ....325
# NUMS: [213, 325] 69225
# ...16...
# ..957..
# ...*...
# ...503.
# NUMS: [957, 503] 481371
# ..957..
# ...*...
# ...503.
# NUMS: [957, 503] 481371
# ...17...
# ....457
# 03.*...
# ...612.
# NUMS: [457, 612] 279684
# ....457
# 03.*...
# ...612.
# NUMS: [457, 612] 279684
# ....457
# 03.*...
# ...612.
# NUMS: [457, 612] 279684
# ....457
# 03.*...
# ...612.
# NUMS: [457, 612] 279684
# ....457
# 03.*...
# ...612.
# NUMS: [457, 612] 279684
# ....457
# 03.*...
# ...612.
# NUMS: [457, 612] 279684
# ...18...
# ..563..
# 7..*...
# ....44.
# NUMS: [563, 44] 24772
# ..563..
# 7..*...
# ....44.
# NUMS: [563, 44] 24772
# ...19...
# 941....
# ...*383
# .......
# NUMS: [941, 383] 360403
# 941....
# ...*383
# .......
# NUMS: [941, 383] 360403
# ...20...
# ....911
# 116*...
# .......
# NUMS: [911, 116] 105676
# ....911
# 116*...
# .......
# NUMS: [911, 116] 105676
# ....911
# 116*...
# .......
# NUMS: [911, 116] 105676
# ....911
# 116*...
# .......
# NUMS: [911, 116] 105676
# ...21...
# .......
# 118*...
# .......
# NUMS: [118] 118
# .......
# 118*...
# .......
# NUMS: [118] 118
# .......
# 118*...
# .......
# NUMS: [118] 118
# .......
# 118*...
# .......
# NUMS: [118] 118
# ...22...
# ....968
# ...*...
# ....83.
# NUMS: [968, 83] 80344
# ....968
# ...*...
# ....83.
# NUMS: [968, 83] 80344
# ....968
# ...*...
# ....83.
# NUMS: [968, 83] 80344
# ...23...
# ....304
# ...*...
# 761..75
# NUMS: [304, 761] 231344
# ....304
# ...*...
# 761..75
# NUMS: [304, 761] 231344
# ....304
# ...*...
# 761..75
# NUMS: [304, 761] 231344
# ....304
# ...*...
# 761..75
# NUMS: [304, 761] 231344
# ....304
# ...*...
# 761..75
# NUMS: [304, 761] 231344
# ...24...
# ...373.
# ...*...
# .115..5
# NUMS: [373, 115] 42895
# ...373.
# ...*...
# .115..5
# NUMS: [373, 115] 42895
# ...25...
# 934....
# ...*...
# ..697..
# NUMS: [934, 697] 650998
# 934....
# ...*...
# ..697..
# NUMS: [934, 697] 650998
# 934....
# ...*...
# ..697..
# NUMS: [934, 697] 650998
# ...26...
# ...393.
# 7..*...
# ....374
# NUMS: [393, 374] 146982
# ...393.
# 7..*...
# ....374
# NUMS: [393, 374] 146982
# ...393.
# 7..*...
# ....374
# NUMS: [393, 374] 146982
# ...393.
# 7..*...
# ....374
# NUMS: [393, 374] 146982
# ...27...
# ..41...
# ...*...
# 774..37
# NUMS: [41, 774] 31734
# ..41...
# ...*...
# 774..37
# NUMS: [41, 774] 31734
# ..41...
# ...*...
# 774..37
# NUMS: [41, 774] 31734
# ...28...
# .......
# 122*...
# .......
# NUMS: [122] 122
# ...29...
# .......
# 873*...
# ....802
# NUMS: [873, 802] 700146
# .......
# 873*...
# ....802
# NUMS: [873, 802] 700146
# .......
# 873*...
# ....802
# NUMS: [873, 802] 700146
# .......
# 873*...
# ....802
# NUMS: [873, 802] 700146
# .......
# 873*...
# ....802
# NUMS: [873, 802] 700146
# .......
# 873*...
# ....802
# NUMS: [873, 802] 700146
# ...30...
# ..819..
# 2..*...
# ......2
# NUMS: [819] 819
# ..819..
# 2..*...
# ......2
# NUMS: [819] 819
# ...31...
# 64.....
# ...*556
# 972....
# NUMS: [556, 972] 540432
# 64.....
# ...*556
# 972....
# NUMS: [556, 972] 540432
# 64.....
# ...*556
# 972....
# NUMS: [556, 972] 540432
# 64.....
# ...*556
# 972....
# NUMS: [556, 972] 540432
# 64.....
# ...*556
# 972....
# NUMS: [556, 972] 540432
# ...32...
# .......
# .91*614
# .......
# NUMS: [91, 614] 55874
# ...33...
# .541...
# ...*.98
# ..89...
# NUMS: [541, 89] 48149
# .541...
# ...*.98
# ..89...
# NUMS: [541, 89] 48149
# .541...
# ...*.98
# ..89...
# NUMS: [541, 89] 48149
# .541...
# ...*.98
# ..89...
# NUMS: [541, 89] 48149
# ...34...
# ...680.
# ...*...
# ....390
# NUMS: [680, 390] 265200
# ...680.
# ...*...
# ....390
# NUMS: [680, 390] 265200
# ...680.
# ...*...
# ....390
# NUMS: [680, 390] 265200
# ...680.
# ...*...
# ....390
# NUMS: [680, 390] 265200
# ...35...
# ..439..
# ...*...
# .551.10
# NUMS: [439, 551] 241889
# ...36...
# .......
# 463*649
# .......
# NUMS: [463, 649] 300487
# ...37...
# .102...
# ...*...
# 622....
# NUMS: [102, 622] 63444
# .102...
# ...*...
# 622....
# NUMS: [102, 622] 63444
# .102...
# ...*...
# 622....
# NUMS: [102, 622] 63444
# .102...
# ...*...
# 622....
# NUMS: [102, 622] 63444
# .102...
# ...*...
# 622....
# NUMS: [102, 622] 63444
# .102...
# ...*...
# 622....
# NUMS: [102, 622] 63444
# .102...
# ...*...
# 622....
# NUMS: [102, 622] 63444
# .102...
# ...*...
# 622....
# NUMS: [102, 622] 63444
# ...38...
# ...214.
# ...*...
# ...893.
# NUMS: [214, 893] 191102
# ...214.
# ...*...
# ...893.
# NUMS: [214, 893] 191102
# ...214.
# ...*...
# ...893.
# NUMS: [214, 893] 191102
# ...39...
# ...835.
# ...*...
# ..622..
# NUMS: [835, 622] 519370
# ...835.
# ...*...
# ..622..
# NUMS: [835, 622] 519370
# ...835.
# ...*...
# ..622..
# NUMS: [835, 622] 519370
# ...835.
# ...*...
# ..622..
# NUMS: [835, 622] 519370
# ...40...
# ....246
# ...*...
# ....407
# NUMS: [246, 407] 100122
# ....246
# ...*...
# ....407
# NUMS: [246, 407] 100122
# ....246
# ...*...
# ....407
# NUMS: [246, 407] 100122
# ...41...
# 681....
# ...*159
# .......
# NUMS: [681, 159] 108279
# 681....
# ...*159
# .......
# NUMS: [681, 159] 108279
# 681....
# ...*159
# .......
# NUMS: [681, 159] 108279
# 681....
# ...*159
# .......
# NUMS: [681, 159] 108279
# ...43...
# 967....
# ...*...
# ...149.
# NUMS: [967, 149] 144083
# 967....
# ...*...
# ...149.
# NUMS: [967, 149] 144083
# 967....
# ...*...
# ...149.
# NUMS: [967, 149] 144083
# 967....
# ...*...
# ...149.
# NUMS: [967, 149] 144083
# ...44...
# .539...
# ...*...
# ....810
# NUMS: [539, 810] 436590
# .539...
# ...*...
# ....810
# NUMS: [539, 810] 436590
# ...45...
# .400...
# ...*...
# 6...483
# NUMS: [400, 483] 193200
# .400...
# ...*...
# 6...483
# NUMS: [400, 483] 193200
# .400...
# ...*...
# 6...483
# NUMS: [400, 483] 193200
# .400...
# ...*...
# 6...483
# NUMS: [400, 483] 193200
# ...46...
# ..168..
# ...*...
# ....268
# NUMS: [168, 268] 45024
# ...47...
# 750.108
# ...*...
# .......
# NUMS: [750, 108] 81000
# 750.108
# ...*...
# .......
# NUMS: [750, 108] 81000
# ...49...
# .......
# 692*505
# .......
# NUMS: [692, 505] 349460
# .......
# 692*505
# .......
# NUMS: [692, 505] 349460
# ...50...
# ...529.
# ...*...
# 854..25
# NUMS: [529, 854] 451766
# ...529.
# ...*...
# 854..25
# NUMS: [529, 854] 451766
# ...51...
# .137...
# ...*...
# ..376..
# NUMS: [137, 376] 51512
# .137...
# ...*...
# ..376..
# NUMS: [137, 376] 51512
# ...52...
# ...258.
# ...*...
# ...866.
# NUMS: [258, 866] 223428
# ...258.
# ...*...
# ...866.
# NUMS: [258, 866] 223428
# ...258.
# ...*...
# ...866.
# NUMS: [258, 866] 223428
# ...258.
# ...*...
# ...866.
# NUMS: [258, 866] 223428
# ...53...
# 50..10.
# ...*...
# 82.310.
# NUMS: [10, 310] 3100
# ...54...
# ..730..
# ...*...
# ...256.
# NUMS: [730, 256] 186880
# ..730..
# ...*...
# ...256.
# NUMS: [730, 256] 186880
# ...55...
# .......
# 129*...
# ....910
# NUMS: [129, 910] 117390
# .......
# 129*...
# ....910
# NUMS: [129, 910] 117390
# .......
# 129*...
# ....910
# NUMS: [129, 910] 117390
# ...56...
# .......
# ...*...
# 247.855
# NUMS: [247, 855] 211185
# .......
# ...*...
# 247.855
# NUMS: [247, 855] 211185
# ...57...
# ....54.
# ...*...
# ....322
# NUMS: [54, 322] 17388
# ....54.
# ...*...
# ....322
# NUMS: [54, 322] 17388
# ...58...
# 55.....
# ...*...
# .509...
# NUMS: [509] 509
# 55.....
# ...*...
# .509...
# NUMS: [509] 509
# 55.....
# ...*...
# .509...
# NUMS: [509] 509
# 55.....
# ...*...
# .509...
# NUMS: [509] 509
# ...59...
# 235....
# ...*...
# ....805
# NUMS: [235, 805] 189175
# 235....
# ...*...
# ....805
# NUMS: [235, 805] 189175
# 235....
# ...*...
# ....805
# NUMS: [235, 805] 189175
# ...60...
# .......
# 793*831
# .......
# NUMS: [793, 831] 658983
# ...61...
# 5.871..
# ...*..3
# .147...
# NUMS: [871, 147] 128037
# 5.871..
# ...*..3
# .147...
# NUMS: [871, 147] 128037
# 5.871..
# ...*..3
# .147...
# NUMS: [871, 147] 128037
# 5.871..
# ...*..3
# .147...
# NUMS: [871, 147] 128037
# 5.871..
# ...*..3
# .147...
# NUMS: [871, 147] 128037
# 5.871..
# ...*..3
# .147...
# NUMS: [871, 147] 128037
# ...63...
# ....426
# ...*...
# 257....
# NUMS: [426, 257] 109482
# ....426
# ...*...
# 257....
# NUMS: [426, 257] 109482
# ...64...
# ..285..
# ...*...
# .396...
# NUMS: [285, 396] 112860
# ..285..
# ...*...
# .396...
# NUMS: [285, 396] 112860
# ...65...
# ..499..
# ...*...
# ..548.7
# NUMS: [499, 548] 273452
# ..499..
# ...*...
# ..548.7
# NUMS: [499, 548] 273452
# ..499..
# ...*...
# ..548.7
# NUMS: [499, 548] 273452
# ...66...
# .......
# 504*...
# .......
# NUMS: [504] 504
# .......
# 504*...
# .......
# NUMS: [504] 504
# .......
# 504*...
# .......
# NUMS: [504] 504
# .......
# 504*...
# .......
# NUMS: [504] 504
# .......
# 504*...
# .......
# NUMS: [504] 504
# ...67...
# .......
# ...*576
# 901....
# NUMS: [576, 901] 518976
# .......
# ...*576
# 901....
# NUMS: [576, 901] 518976
# .......
# ...*576
# 901....
# NUMS: [576, 901] 518976
# ...69...
# ...551.
# ...*...
# .......
# NUMS: [551] 551
# ...551.
# ...*...
# .......
# NUMS: [551] 551
# ...70...
# ....722
# ...*...
# 87.311.
# NUMS: [722, 311] 224542
# ....722
# ...*...
# 87.311.
# NUMS: [722, 311] 224542
# ...71...
# .39....
# ...*...
# 7.651..
# NUMS: [39, 651] 25389
# .39....
# ...*...
# 7.651..
# NUMS: [39, 651] 25389
# .39....
# ...*...
# 7.651..
# NUMS: [39, 651] 25389
# ...72...
# .329...
# ...*...
# .627...
# NUMS: [329, 627] 206283
# .329...
# ...*...
# .627...
# NUMS: [329, 627] 206283
# .329...
# ...*...
# .627...
# NUMS: [329, 627] 206283
# .329...
# ...*...
# .627...
# NUMS: [329, 627] 206283
# .329...
# ...*...
# .627...
# NUMS: [329, 627] 206283
# .329...
# ...*...
# .627...
# NUMS: [329, 627] 206283
# ...73...
# ..666..
# ...*...
# 172....
# NUMS: [666, 172] 114552
# ..666..
# ...*...
# 172....
# NUMS: [666, 172] 114552
# ..666..
# ...*...
# 172....
# NUMS: [666, 172] 114552
# ...74...
# .......
# 295*...
# ....163
# NUMS: [295, 163] 48085
# ...75...
# 56..76.
# ...*...
# ..199..
# NUMS: [76, 199] 15124
# 56..76.
# ...*...
# ..199..
# NUMS: [76, 199] 15124
# 56..76.
# ...*...
# ..199..
# NUMS: [76, 199] 15124
# ...76...
# .......
# 97.*...
# ....647
# NUMS: [647] 647
# ...77...
# 841...1
# ...*...
# ....88.
# NUMS: [841, 88] 74008
# 841...1
# ...*...
# ....88.
# NUMS: [841, 88] 74008
# ...78...
# 122....
# ...*582
# .......
# NUMS: [122, 582] 71004
# 122....
# ...*582
# .......
# NUMS: [122, 582] 71004
# ...79...
# 221..50
# ...*...
# ...884.
# NUMS: [221, 884] 195364
# 221..50
# ...*...
# ...884.
# NUMS: [221, 884] 195364
# 221..50
# ...*...
# ...884.
# NUMS: [221, 884] 195364
# 221..50
# ...*...
# ...884.
# NUMS: [221, 884] 195364
# 221..50
# ...*...
# ...884.
# NUMS: [221, 884] 195364
# ...80...
# .......
# ...*155
# .70....
# NUMS: [155, 70] 10850
# .......
# ...*155
# .70....
# NUMS: [155, 70] 10850
# ...81...
# 200...8
# ...*...
# ...491.
# NUMS: [200, 491] 98200
# 200...8
# ...*...
# ...491.
# NUMS: [200, 491] 98200
# 200...8
# ...*...
# ...491.
# NUMS: [200, 491] 98200
# ...82...
# ..203..
# ...*...
# ....908
# NUMS: [203, 908] 184324
# ..203..
# ...*...
# ....908
# NUMS: [203, 908] 184324
# ..203..
# ...*...
# ....908
# NUMS: [203, 908] 184324
# ...83...
# 282....
# ...*...
# .255...
# NUMS: [282, 255] 71910
# 282....
# ...*...
# .255...
# NUMS: [282, 255] 71910
# ...84...
# .216...
# ...*...
# ..91...
# NUMS: [216, 91] 19656
# .216...
# ...*...
# ..91...
# NUMS: [216, 91] 19656
# ...85...
# ....657
# .15*...
# .......
# NUMS: [657, 15] 9855
# ....657
# .15*...
# .......
# NUMS: [657, 15] 9855
# ....657
# .15*...
# .......
# NUMS: [657, 15] 9855
# ...87...
# ...104.
# ...*...
# ..152..
# NUMS: [104, 152] 15808
# ...104.
# ...*...
# ..152..
# NUMS: [104, 152] 15808
# ...88...
# ..376.8
# ...*...
# ..536..
# NUMS: [376, 536] 201536
# ..376.8
# ...*...
# ..536..
# NUMS: [376, 536] 201536
# ..376.8
# ...*...
# ..536..
# NUMS: [376, 536] 201536
# ..376.8
# ...*...
# ..536..
# NUMS: [376, 536] 201536
# ...89...
# .545...
# ...*...
# .147...
# NUMS: [545, 147] 80115
# .545...
# ...*...
# .147...
# NUMS: [545, 147] 80115
# .545...
# ...*...
# .147...
# NUMS: [545, 147] 80115
# ...90...
# ....471
# ...*...
# .......
# NUMS: [471] 471
# ...91...
# .......
# ...*123
# 850....
# NUMS: [123, 850] 104550
# .......
# ...*123
# 850....
# NUMS: [123, 850] 104550
# ...92...
# .......
# 259*577
# .......
# NUMS: [259, 577] 149443
# .......
# 259*577
# .......
# NUMS: [259, 577] 149443
# ...93...
# .922...
# ...*..5
# .663...
# NUMS: [922, 663] 611286
# .922...
# ...*..5
# .663...
# NUMS: [922, 663] 611286
# .922...
# ...*..5
# .663...
# NUMS: [922, 663] 611286
# .922...
# ...*..5
# .663...
# NUMS: [922, 663] 611286
# ...94...
# ...394.
# ...*...
# .46....
# NUMS: [394, 46] 18124
# ...394.
# ...*...
# .46....
# NUMS: [394, 46] 18124
# ...95...
# ....764
# ...*...
# .538...
# NUMS: [764, 538] 411032
# ...96...
# ...705.
# ...*...
# ....803
# NUMS: [705, 803] 566115
# ...705.
# ...*...
# ....803
# NUMS: [705, 803] 566115
# ...705.
# ...*...
# ....803
# NUMS: [705, 803] 566115
# ...97...
# ...808.
# 66.*...
# ...473.
# NUMS: [808, 473] 382184
# ...808.
# 66.*...
# ...473.
# NUMS: [808, 473] 382184
# ...808.
# 66.*...
# ...473.
# NUMS: [808, 473] 382184
# ...99...
# ....656
# ...*...
# 2..153.
# NUMS: [656, 153] 100368
# ...100...
# 72..131
# ...*...
# ...821.
# NUMS: [131, 821] 107551
# 72..131
# ...*...
# ...821.
# NUMS: [131, 821] 107551
# 72..131
# ...*...
# ...821.
# NUMS: [131, 821] 107551
# ...101...
# .....30
# ...*...
# ..857.8
# NUMS: [857] 857
# ...102...
# .172...
# ...*...
# .......
# NUMS: [172] 172
# .172...
# ...*...
# .......
# NUMS: [172] 172
# .172...
# ...*...
# .......
# NUMS: [172] 172
# .172...
# ...*...
# .......
# NUMS: [172] 172
# .172...
# ...*...
# .......
# NUMS: [172] 172
# .172...
# ...*...
# .......
# NUMS: [172] 172
# ...103...
# ....325
# ...*...
# ..453..
# NUMS: [325, 453] 147225
# ....325
# ...*...
# ..453..
# NUMS: [325, 453] 147225
# ....325
# ...*...
# ..453..
# NUMS: [325, 453] 147225
# ...104...
# .607.17
# ...*...
# 99.596.
# NUMS: [607, 596] 361772
# .607.17
# ...*...
# 99.596.
# NUMS: [607, 596] 361772
# .607.17
# ...*...
# 99.596.
# NUMS: [607, 596] 361772
# ...105...
# .......
# 597*813
# .......
# NUMS: [597, 813] 485361
# .......
# 597*813
# .......
# NUMS: [597, 813] 485361
# ...106...
# .......
# 931*...
# ....839
# NUMS: [931, 839] 781109
# .......
# 931*...
# ....839
# NUMS: [931, 839] 781109
# ...107...
# .......
# .43*...
# ....234
# NUMS: [43, 234] 10062
# .......
# .43*...
# ....234
# NUMS: [43, 234] 10062
# .......
# .43*...
# ....234
# NUMS: [43, 234] 10062
# ...108...
# ...424.
# ...*...
# ...907.
# NUMS: [424, 907] 384568
# ...424.
# ...*...
# ...907.
# NUMS: [424, 907] 384568
# ...424.
# ...*...
# ...907.
# NUMS: [424, 907] 384568
# ...109...
# .......
# 100*...
# ....268
# NUMS: [100, 268] 26800
# .......
# 100*...
# ....268
# NUMS: [100, 268] 26800
# ...110...
# .159...
# ...*...
# ....815
# NUMS: [159, 815] 129585
# .159...
# ...*...
# ....815
# NUMS: [159, 815] 129585
# ...111...
# .893...
# ...*...
# .568...
# NUMS: [893, 568] 507224
# .893...
# ...*...
# .568...
# NUMS: [893, 568] 507224
# ...112...
# ...355.
# ...*...
# ..132..
# NUMS: [355, 132] 46860
# ...355.
# ...*...
# ..132..
# NUMS: [355, 132] 46860
# ...355.
# ...*...
# ..132..
# NUMS: [355, 132] 46860
# ...355.
# ...*...
# ..132..
# NUMS: [355, 132] 46860
# ...355.
# ...*...
# ..132..
# NUMS: [355, 132] 46860
# ...113...
# 513....
# ...*...
# 454....
# NUMS: [513, 454] 232902
# 513....
# ...*...
# 454....
# NUMS: [513, 454] 232902
# ...114...
# ...424.
# ...*...
# .650...
# NUMS: [424, 650] 275600
# ...424.
# ...*...
# .650...
# NUMS: [424, 650] 275600
# ...115...
# 730...4
# ...*...
# ..488.4
# NUMS: [730, 488] 356240
# 730...4
# ...*...
# ..488.4
# NUMS: [730, 488] 356240
# 730...4
# ...*...
# ..488.4
# NUMS: [730, 488] 356240
# ...116...
# .......
# ...*...
# 86.981.
# NUMS: [981] 981
# ...117...
# 458....
# ...*...
# .652...
# NUMS: [458, 652] 298616
# 458....
# ...*...
# .652...
# NUMS: [458, 652] 298616
# 458....
# ...*...
# .652...
# NUMS: [458, 652] 298616
# 458....
# ...*...
# .652...
# NUMS: [458, 652] 298616
# ...118...
# ....86.
# ...*...
# ...845.
# NUMS: [86, 845] 72670
# ....86.
# ...*...
# ...845.
# NUMS: [86, 845] 72670
# ....86.
# ...*...
# ...845.
# NUMS: [86, 845] 72670
# ....86.
# ...*...
# ...845.
# NUMS: [86, 845] 72670
# ...119...
# .519...
# ...*.36
# .189...
# NUMS: [519, 189] 98091
# .519...
# ...*.36
# .189...
# NUMS: [519, 189] 98091
# .519...
# ...*.36
# .189...
# NUMS: [519, 189] 98091
# .519...
# ...*.36
# .189...
# NUMS: [519, 189] 98091
# ...120...
# 45.512.
# ...*...
# ...466.
# NUMS: [512, 466] 238592
# ...121...
# ....5..
# 741*...
# .......
# NUMS: [5, 741] 3705
# ....5..
# 741*...
# .......
# NUMS: [5, 741] 3705
# ....5..
# 741*...
# .......
# NUMS: [5, 741] 3705
# ...122...
# .710...
# ...*...
# 73.980.
# NUMS: [710, 980] 695800
# ...123...
# .......
# ...*...
# 442.432
# NUMS: [442, 432] 190944
# .......
# ...*...
# 442.432
# NUMS: [442, 432] 190944
# .......
# ...*...
# 442.432
# NUMS: [442, 432] 190944
# .......
# ...*...
# 442.432
# NUMS: [442, 432] 190944
# ...124...
# ..273..
# 2..*...
# ....869
# NUMS: [273, 869] 237237
# ..273..
# 2..*...
# ....869
# NUMS: [273, 869] 237237
# ..273..
# 2..*...
# ....869
# NUMS: [273, 869] 237237
# ..273..
# 2..*...
# ....869
# NUMS: [273, 869] 237237
# ...125...
# .......
# 233*559
# .......
# NUMS: [233, 559] 130247
# .......
# 233*559
# .......
# NUMS: [233, 559] 130247
# ...126...
# 884.731
# ...*...
# .......
# NUMS: [884, 731] 646204
# 884.731
# ...*...
# .......
# NUMS: [884, 731] 646204
# 884.731
# ...*...
# .......
# NUMS: [884, 731] 646204
# ...127...
# 231....
# ...*981
# .......
# NUMS: [231, 981] 226611
# 231....
# ...*981
# .......
# NUMS: [231, 981] 226611
# 231....
# ...*981
# .......
# NUMS: [231, 981] 226611
# ...128...
# .637...
# ...*...
# ..114..
# NUMS: [637, 114] 72618
# .637...
# ...*...
# ..114..
# NUMS: [637, 114] 72618
# ...129...
# ...205.
# ...*...
# .367.*.
# NUMS: [205, 367] 75235
# ...205.
# ...*...
# .367.*.
# NUMS: [205, 367] 75235
# ...205.
# ...*...
# .367.*.
# NUMS: [205, 367] 75235
# ...130...
# ...353.
# ...*...
# ....870
# NUMS: [353, 870] 307110
# ...353.
# ...*...
# ....870
# NUMS: [353, 870] 307110
# ...353.
# ...*...
# ....870
# NUMS: [353, 870] 307110
# ...131...
# .478...
# ...*...
# ...921.
# NUMS: [478, 921] 440238
# .478...
# ...*...
# ...921.
# NUMS: [478, 921] 440238
# .478...
# ...*...
# ...921.
# NUMS: [478, 921] 440238
# .478...
# ...*...
# ...921.
# NUMS: [478, 921] 440238
# ...132...
# .......
# 978*368
# .......
# NUMS: [978, 368] 359904
# .......
# 978*368
# .......
# NUMS: [978, 368] 359904
# .......
# 978*368
# .......
# NUMS: [978, 368] 359904
# .......
# 978*368
# .......
# NUMS: [978, 368] 359904
# ...133...
# 416...6
# ...*...
# .748...
# NUMS: [416, 748] 311168
# 416...6
# ...*...
# .748...
# NUMS: [416, 748] 311168
# ...135...
# .......
# ...*...
# 701.797
# NUMS: [701, 797] 558697
# .......
# ...*...
# 701.797
# NUMS: [701, 797] 558697
# .......
# ...*...
# 701.797
# NUMS: [701, 797] 558697
# .......
# ...*...
# 701.797
# NUMS: [701, 797] 558697
# ...136...
# 940....
# ...*...
# 649....
# NUMS: [940, 649] 610060
# ...137...
# .....76
# 7..*...
# ...721.
# NUMS: [721] 721
# ...138...
# 101....
# ...*376
# .......
# NUMS: [101, 376] 37976
# ...139...
# .869...
# ...*...
# ...475.
# NUMS: [869, 475] 412775
# ...140...
# ..913..
# ...*...
# ....383
# NUMS: [913, 383] 349679
# ..913..
# ...*...
# ....383
# NUMS: [913, 383] 349679
# ..913..
# ...*...
# ....383
# NUMS: [913, 383] 349679
# ..913..
# ...*...
# ....383
# NUMS: [913, 383] 349679
# ..913..
# ...*...
# ....383
# NUMS: [913, 383] 349679
# 80146409
